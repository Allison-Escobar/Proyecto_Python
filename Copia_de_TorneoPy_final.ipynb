# %% [markdown]
# <a href="https://colab.research.google.com/github/Allison-Escobar/Proyecto_Python/blob/main/Copia_de_TorneoPy_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Actividad de aprendizaje M2.6*
#
# * **Nombre:** Allison Noelia Escobar Palacios
# * **Grupo:** Estudiante que cursara 2do año
# * **saludo:** ¡¡A darle, que hoy se gana!!

# %%
print( "¡¡¡Hola y bienvenidos al Torneo Python!!!")
# Out:
# ¡¡¡Hola y bienvenidos al Torneo Python!!!

# %% [markdown]
# **¿Qué crees que se puede hacer con la programación en los videojuegos?**
#
# A mi parecer, siento y creo que los videojuegos pueden ser más complejos y mejor hechos, pues les da mas sentido y mejores graficos o que funcione mejor.

# %%
Jugador = "Escobar17"
vida = 70
escudos = 30
kills = 3
monedas = 250

# El jugador perdio vida
vida = vida - 25

# Recompensa por victoria
monedas = monedas + 100

# Puntaje total obtenido por cada kill que vale 10 puntos
Puntaje_total = kills * 10

print("Jugador:", Jugador)
print("Vida:", vida)
print("Escudos:", escudos)
print("Puntaje por kills:", Puntaje_total)
print("Monedas:", monedas)

# Calcular puntaje
def calcular_puntaje(kills, asistencias):
    puntaje = kills * 10 + asistencias * 5
    return puntaje

# Sumar vida
def ganar_vida(vida, cantidad):
    return vida + cantidad

# Sumar escudos
def ganar_escudos(escudos, cantidad):
    return escudos + cantidad


# Ejemplos de puntaje
print("Puntaje 1 (10 kills, 5 asistencias):", calcular_puntaje(10, 5))
print("Puntaje 2 (0 kills, 3 asistencias):", calcular_puntaje(0, 3))
print("Puntaje 3 (20 kills, 10 asistencias):", calcular_puntaje(20, 10))


# Ganar vida y escudos
vida = ganar_vida(vida, 20)
escudos = ganar_escudos(escudos, 15)

print("Nueva vida:", vida)
print("Nuevos escudos:", escudos)

# Pedir nombre y puntaje
nombre = input("Nombre del jugador: ")
puntaje = int(input("Puntaje obtenido: "))

# Si el puntaje es mayor o igual a 50 ---> “Clasificaste a la siguiente ronda”.

# En caso de puntaje negativo
if puntaje < 0:
    print("Error: puntaje no válido")
else:

# En caso de clasificar
 if puntaje >= 50:
     print("Clasificaste a la siguiente ronda")
 else:
     print("No clasificaste")

# Simulación 5 rondas automáticas
 for ronda in range(1, 6):
     print(f"Ronda {ronda}: En juego...")


# Jugadores en lista
jugadores = ["Player1", "Player2", "Player3"]

# Lista de puntajes
puntajes = [80, 40, 95]

# El gugador con mayor puntaje
mayor_puntaje = max(puntajes)
indice = puntajes.index(mayor_puntaje)
print("Jugador con mayor puntaje:", jugadores[indice])

# Diccionario jugador + puntaje
jugadores_dic = {
    jugadores[0]: puntajes[0],
    jugadores[1]: puntajes[1],
    jugadores[2]: puntajes[2]
}
print("Diccionario:", jugadores_dic)

# Top 3 de mayor a menor
ranking = sorted(jugadores_dic.items(), reverse=True, key=lambda x: x[1])

print("\nTop 3:")
print(ranking)
# Out:
# Jugador: Escobar17
# Vida: 45
# Escudos: 30
# Puntaje por kills: 30
# Monedas: 350
# Puntaje 1 (10 kills, 5 asistencias): 125
# Puntaje 2 (0 kills, 3 asistencias): 15
# Puntaje 3 (20 kills, 10 asistencias): 250
# Nueva vida: 65
# Nuevos escudos: 45
# Nombre del jugador: aly
# Puntaje obtenido: 59
# Clasificaste a la siguiente ronda
# Ronda 1: En juego...
# Ronda 2: En juego...
# Ronda 3: En juego...
# Ronda 4: En juego...
# Ronda 5: En juego...
# Jugador con mayor puntaje: Player3
# Diccionario: {'Player1': 80, 'Player2': 40, 'Player3': 95}
#
# Top 3:
# [('Player3', 95), ('Player1', 80), ('Player2', 40)]
